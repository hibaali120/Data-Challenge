# %%
#Data Challenge 
#Author: Hiba Ali 
#E-mail: hiba.ali.26@dartmouth.edu

#Objectives:
#1. Where should we deploy a food access program?
#2. How many people will be included? How many might be successfully engaged?
#3. Which subgroup of the population might benefit the most from the program?
#4. What is the projected impact of this program?

# %%
#import libraries
import pandas as pd 
import sqlite3
import os

#path to database from the data folder
connection = sqlite3.connect(os.path.join('..', 'data', 'challenge.db'))

#see the table names 
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", connection)
print(tables)
# Out:
#                   name
# 0  five_hundred_cities
# 1               access
# 2        variable_list

# %%
#names of the tables are five_hundred_cities, access, and variable_list

#load the tables into dataframes
df_cities = pd.read_sql_query("SELECT * FROM five_hundred_cities;", connection)
df_cities.head()
# Out:
#    index StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0      0        AL  Birmingham     107000  1073000100  0107000-01073000100
# 1      1        AL  Birmingham     107000  1073000300  0107000-01073000300
# 2      2        AL  Birmingham     107000  1073000400  0107000-01073000400
# 3      3        AL  Birmingham     107000  1073000500  0107000-01073000500
# 4      4        AL  Birmingham     107000  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               24.4      (21.2, 27.8)                 31.2
# 1            2735               30.4      (27.1, 33.7)                 30.5
# 2            3338               24.7      (21.1, 28.5)                 31.5
# 3            2864               25.2      (21.6, 29.0)                 35.0
# 4            2577               29.0      (24.5, 33.8)                 36.3
#
#    ... PAPTEST_Crude95CI  PHLTH_CrudePrev PHLTH_Crude95CI  SLEEP_CrudePrev  \
# 0  ...      (83.4, 86.6)             20.5    (18.9, 22.2)             45.5
# 1  ...      (81.9, 85.6)             22.2    (20.4, 24.0)             44.5
# 2  ...      (82.3, 86.8)             19.4    (17.5, 21.4)             45.7
# 3  ...      (82.1, 86.5)             21.7    (19.7, 23.9)             46.1
# 4  ...      (82.2, 87.1)             25.5    (23.1, 28.0)             48.3
#
#   SLEEP_Crude95CI  STROKE_CrudePrev STROKE_Crude95CI  TEETHLOST_CrudePrev  \
# 0    (44.3, 46.5)               5.5     ( 5.0,  5.9)                 28.9
# 1    (43.2, 45.7)               6.1     ( 5.5,  6.8)                 32.9
# 2    (44.2, 47.0)               5.6     ( 5.0,  6.2)                 28.6
# 3    (44.5, 47.4)               7.3     ( 6.5,  8.2)                 34.0
# 4    (46.6, 49.7)               9.0     ( 8.1, 10.0)                 43.2
#
#   TEETHLOST_Crude95CI                       Geolocation
# 0        (23.7, 35.1)  (33.57943283260, -86.7228323926)
# 1        (25.5, 40.2)  (33.54282086860, -86.7524339780)
# 2        (22.0, 35.1)  (33.56324496330, -86.7640474064)
# 3        (24.4, 42.9)  (33.54424045940, -86.7749130719)
# 4        (33.2, 53.2)  (33.55254061390, -86.8016893706)
#
# [5 rows x 64 columns]

# %%
#load the tables into dataframes
df_access = pd.read_sql_query("SELECT * FROM access;", connection)
df_access.head()
# Out:
#    index  FIPS State   County  LACCESS_POP10  LACCESS_POP15  \
# 0      0  1001    AL  Autauga   18428.439685   17496.693038
# 1      1  1003    AL  Baldwin   35210.814078   30561.264430
# 2      2  1005    AL  Barbour    5722.305602    6069.523628
# 3      3  1007    AL     Bibb    1044.867327     969.378841
# 4      4  1009    AL   Blount    1548.175559    3724.428242
#
#    PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# 0              -5.056026          33.769657          32.062255
# 1             -13.204891          19.318473          16.767489
# 2               6.067799          20.840972          22.105560
# 3              -7.224696           4.559753           4.230324
# 4             140.568857           2.700840           6.497380
#
#    LACCESS_LOWI10  ...  LACCESS_HISP15  PCT_LACCESS_HISP15  LACCESS_NHASIAN15  \
# 0     5344.427472  ...      471.136164            0.863345          86.767975
# 1     9952.144027  ...     1377.874834            0.755973         212.946378
# 2     3135.676086  ...      509.377525            1.855183          17.096410
# 3      491.449066  ...        8.596762            0.037516           1.994318
# 4      609.027708  ...      497.489891            0.867886           8.428994
#
#    PCT_LACCESS_NHASIAN15  LACCESS_NHNA15  PCT_LACCESS_NHNA15  LACCESS_NHPI15  \
# 0               0.159000       61.169869            0.112092        8.817961
# 1               0.116833      181.649648            0.099662       14.819634
# 2               0.062266       39.960527            0.145539        8.082376
# 3               0.008703        2.513097            0.010967        0.000000
# 4               0.014705       28.938242            0.050484        1.062851
#
#    PCT_LACCESS_NHPI15  LACCESS_MULTIR15  PCT_LACCESS_MULTIR15
# 0            0.016159        482.848633              0.884808
# 1            0.008131       1127.696098              0.618712
# 2            0.029436        462.382655              1.684025
# 3            0.000000          5.259244              0.022951
# 4            0.001854        202.914187              0.353990
#
# [5 rows x 45 columns]

# %%
#load the tables into dataframes
df_variables = pd.read_sql_query("SELECT * FROM variable_list;", connection)
df_variables
# Out:
#      index                          Category Name  Category Code  \
# 0        0  Access and Proximity to Grocery Store         ACCESS
# 1        1  Access and Proximity to Grocery Store         ACCESS
# 2        2  Access and Proximity to Grocery Store         ACCESS
# 3        3  Access and Proximity to Grocery Store         ACCESS
# 4        4  Access and Proximity to Grocery Store         ACCESS
# ..     ...                                    ...            ...
# 276    276          Socioeconomic Characteristics  SOCIOECONOMIC
# 277    277          Socioeconomic Characteristics  SOCIOECONOMIC
# 278    278          Socioeconomic Characteristics  SOCIOECONOMIC
# 279    279          Socioeconomic Characteristics  SOCIOECONOMIC
# 280    280          Socioeconomic Characteristics  SOCIOECONOMIC
#
#     Subcategory Name                                      Variable Name  \
# 0            Overall              Population, low access to store, 2010
# 1            Overall              Population, low access to store, 2015
# 2            Overall  Population, low access to store (% change), 20...
# 3            Overall          Population, low access to store (%), 2010
# 4            Overall          Population, low access to store (%), 2015
# ..               ...                                                ...
# 276     Income Level                  Persistent-poverty counties, 2010
# 277     Income Level                           Child poverty rate, 2015
# 278     Income Level            Persistent-child-poverty counties, 2010
# 279            Other                      Metro/nonmetro counties, 2010
# 280            Other                     Population-loss counties, 2010
#
#              Variable Code Geography     Units
# 0            LACCESS_POP10    CNTY10     Count
# 1            LACCESS_POP15    CNTY10     Count
# 2    PCH_LACCESS_POP_10_15    CNTY10  % change
# 3        PCT_LACCESS_POP10    CNTY10   Percent
# 4        PCT_LACCESS_POP15    CNTY10   Percent
# ..                     ...       ...       ...
# 276               PERPOV10    CNTY10    Legend
# 277         CHILDPOVRATE15    CNTY10   Percent
# 278           PERCHLDPOV10    CNTY10    Legend
# 279                METRO13    CNTY10    Legend
# 280              POPLOSS10    CNTY10    Legend
#
# [281 rows x 8 columns]

# %%
#renaming df_access columns for readability using df_variables
mapping = dict(zip(df_variables['Variable Code'], 
                   df_variables['Variable Name']))

df_access = df_access.rename(columns=mapping)

df_access.head()
# Out:
#    index  FIPS State   County  Population, low access to store, 2010  \
# 0      0  1001    AL  Autauga                           18428.439685
# 1      1  1003    AL  Baldwin                           35210.814078
# 2      2  1005    AL  Barbour                            5722.305602
# 3      3  1007    AL     Bibb                            1044.867327
# 4      4  1009    AL   Blount                            1548.175559
#
#    Population, low access to store, 2015  \
# 0                           17496.693038
# 1                           30561.264430
# 2                            6069.523628
# 3                             969.378841
# 4                            3724.428242
#
#    Population, low access to store (% change), 2010 -15  \
# 0                                          -5.056026
# 1                                         -13.204891
# 2                                           6.067799
# 3                                          -7.224696
# 4                                         140.568857
#
#    Population, low access to store (%), 2010  \
# 0                                  33.769657
# 1                                  19.318473
# 2                                  20.840972
# 3                                   4.559753
# 4                                   2.700840
#
#    Population, low access to store (%), 2015  \
# 0                                  32.062255
# 1                                  16.767489
# 2                                  22.105560
# 3                                   4.230324
# 4                                   6.497380
#
#    Low income & low access to store, 2010  ...  \
# 0                             5344.427472  ...
# 1                             9952.144027  ...
# 2                             3135.676086  ...
# 3                              491.449066  ...
# 4                              609.027708  ...
#
#    Hispanic ethnicity, low access to store, 2015  \
# 0                                     471.136164
# 1                                    1377.874834
# 2                                     509.377525
# 3                                       8.596762
# 4                                     497.489891
#
#    Hispanic ethnicity, low access to store (%), 2015  \
# 0                                           0.863345
# 1                                           0.755973
# 2                                           1.855183
# 3                                           0.037516
# 4                                           0.867886
#
#    Asian, low access to store, 2015  Asian, low access to store (%), 2015  \
# 0                         86.767975                              0.159000
# 1                        212.946378                              0.116833
# 2                         17.096410                              0.062266
# 3                          1.994318                              0.008703
# 4                          8.428994                              0.014705
#
#    American Indian or Alaska Native, low access to store, 2015  \
# 0                                          61.169869
# 1                                         181.649648
# 2                                          39.960527
# 3                                           2.513097
# 4                                          28.938242
#
#    American Indian or Alaska Native, low access to store (%), 2015  \
# 0                                           0.112092
# 1                                           0.099662
# 2                                           0.145539
# 3                                           0.010967
# 4                                           0.050484
#
#    Hawaiian or Pacific Islander, low access to store, 2015  \
# 0                                           8.817961
# 1                                          14.819634
# 2                                           8.082376
# 3                                           0.000000
# 4                                           1.062851
#
#    Hawaiian or Pacific Islander, low access to store (%), 2015  \
# 0                                           0.016159
# 1                                           0.008131
# 2                                           0.029436
# 3                                           0.000000
# 4                                           0.001854
#
#    Multiracial, low access to store, 2015  \
# 0                              482.848633
# 1                             1127.696098
# 2                              462.382655
# 3                                5.259244
# 4                              202.914187
#
#    Multiracial, low access to store (%), 2015
# 0                                    0.884808
# 1                                    0.618712
# 2                                    1.684025
# 3                                    0.022951
# 4                                    0.353990
#
# [5 rows x 45 columns]

# %%
#merge the dataframes 
df_cities['FIPS'] = df_cities['TractFIPS'].astype(str).str[:4].astype(int)

df = df_cities.merge(df_access, on='FIPS', how='left')

df.head()
# Out:
#    index_x StateAbbr   PlaceName  FIPS   TractFIPS        Place_TractID  \
# 0        0        AL  Birmingham  1073  1073000100  0107000-01073000100
# 1        1        AL  Birmingham  1073  1073000300  0107000-01073000300
# 2        2        AL  Birmingham  1073  1073000400  0107000-01073000400
# 3        3        AL  Birmingham  1073  1073000500  0107000-01073000500
# 4        4        AL  Birmingham  1073  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               24.4      (21.2, 27.8)                 31.2
# 1            2735               30.4      (27.1, 33.7)                 30.5
# 2            3338               24.7      (21.1, 28.5)                 31.5
# 3            2864               25.2      (21.6, 29.0)                 35.0
# 4            2577               29.0      (24.5, 33.8)                 36.3
#
#    ... Hispanic ethnicity, low access to store, 2015  \
# 0  ...                                   7097.673679
# 1  ...                                   7097.673679
# 2  ...                                   7097.673679
# 3  ...                                   7097.673679
# 4  ...                                   7097.673679
#
#    Hispanic ethnicity, low access to store (%), 2015  \
# 0                                            1.07791
# 1                                            1.07791
# 2                                            1.07791
# 3                                            1.07791
# 4                                            1.07791
#
#   Asian, low access to store, 2015  Asian, low access to store (%), 2015  \
# 0                      1808.048713                              0.274585
# 1                      1808.048713                              0.274585
# 2                      1808.048713                              0.274585
# 3                      1808.048713                              0.274585
# 4                      1808.048713                              0.274585
#
#   American Indian or Alaska Native, low access to store, 2015  \
# 0                                         476.945542
# 1                                         476.945542
# 2                                         476.945542
# 3                                         476.945542
# 4                                         476.945542
#
#    American Indian or Alaska Native, low access to store (%), 2015  \
# 0                                           0.072433
# 1                                           0.072433
# 2                                           0.072433
# 3                                           0.072433
# 4                                           0.072433
#
#   Hawaiian or Pacific Islander, low access to store, 2015  \
# 0                                          80.060491
# 1                                          80.060491
# 2                                          80.060491
# 3                                          80.060491
# 4                                          80.060491
#
#    Hawaiian or Pacific Islander, low access to store (%), 2015  \
# 0                                           0.012159
# 1                                           0.012159
# 2                                           0.012159
# 3                                           0.012159
# 4                                           0.012159
#
#   Multiracial, low access to store, 2015  \
# 0                            6376.995723
# 1                            6376.995723
# 2                            6376.995723
# 3                            6376.995723
# 4                            6376.995723
#
#    Multiracial, low access to store (%), 2015
# 0                                    0.968462
# 1                                    0.968462
# 2                                    0.968462
# 3                                    0.968462
# 4                                    0.968462
#
# [5 rows x 108 columns]

# %%
#Guiding Question 1: Where should we deploy a food access program?
